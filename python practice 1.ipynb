# %%
a = 3
b = 8.6

# %%
type(b)
# Out:
# float

# %%
type(a)
# Out:
# int

# %%
a + b
# Out:
# 11.6

# %% [markdown]
# # python operators
#
# ## Data types

# %%
a * b
# Out:
# 25.799999999999997

# %%
a / b
# Out:
# 0.3488372093023256

# %%
b / a
# Out:
# 2.8666666666666667

# %%
d - a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d - a
#
# NameError: name 'd' is not defined

# %%
b - a
# Out:
# 5.6

# %%
c = 10
d = 2

# %%
c ** d
# Out:
# 100

# %%
d ** c
# Out:
# 1024

# %%
fruit = ['apple', 'orange', 'banana']

# %%
len(fruit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 len(fruit)
#
# NameError: name 'fruit' is not defined

# %%
fruit = ["apple", "banana", "orange"]  # Example fruit list - adjust as needed

# %%
"welcome"

# %%
print("welcome " * 3)
# Out:
# welcome welcome welcome

# %%
fruits = ["Apple", "Orange", "Banana"]
print(fruits)
# Out:
# ['Apple', 'Orange', 'Banana']

# %%
len(fruits)
# Out:
# 3

# %%
num = [12,20,93,34,18,3,10]

# %%
print(num)
# Out:
# [12, 20, 93, 34, 18, 3, 10]

# %% [markdown]
# ## if/ elif else statement

# %%
age = 25
if age >= 18:
    print('you are an adult')
else:
    print('you are a minor')
# Out:
# you are an adult

# %%
age = 25
if age >= 18:
    print('you are an adult')
else:
    print('you are a minor')
